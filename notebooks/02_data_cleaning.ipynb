# %% [markdown]
# # 02. Data Cleaning Validation
#
# This notebook verifies the data cleaning pipeline, comparing raw data statistics against cleaned statistics (e.g. missing values treatment, outlier capping).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
from preprocessing.cleaner import load_raw_data, clean_data

raw_path = r'../../DataSet/Data_Export_Selected_B_167_01_Jan_2025_000000_01_Jul_2025_000000 (2).xlsx'
df_raw = load_raw_data(raw_path)
df_clean = clean_data(df_raw)

print("Missing values in Raw:")
print(df_raw[['Motor_Current', 'Discharge_Pressure', 'Intake_Pressure', 'Motor_Temperature']].isnull().sum())

print("\nMissing values in Cleaned:")
print(df_clean[['Motor_Current', 'Discharge_Pressure', 'Intake_Pressure', 'Motor_Temperature']].isnull().sum())
